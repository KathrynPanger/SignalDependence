# %%
import numpy as np
import librosa
import os
from google.colab import drive
import matplotlib.pyplot as plt
drive.mount('/content/drive')
import IPython.display as ipd
from scipy import signal
import math
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("drive/MyDrive/Colab Notebooks/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-db2d836bbdaa> in <module>()
# ----> 1 os.chdir("drive/MyDrive/Colab Notebooks/")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks/'

# %%
#data1, sr1 = librosa.load("sound_and_vision_halved.mp3")
#data2, sr2 = librosa.load("sound_and_vision300hz_point6amp_halfsecond.mp3")
#data3, sr3 = librosa.load("SandVHZ300_Apointfour_S4.mp3")
#data4, sr4 = librosa.load("sound_and_vision_halved_threetones.mp3")
#data1, sr1 = librosa.load("smallfile.mp3")
#data5, sr5 = librosa.load("smallsquare2.mp3")
#square, srs= librosa.load("smallsquareonly.mp3")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
class soundSample:
  def __init__(self, filename):
    self.name = filename
    self.data = librosa.load(filename)[0]
    self.sr = librosa.load(filename)[1]
    self.t = np.arange(0,len(self.data),1)
    self.n=len(self.data)
    self.fhat=np.fft.fft(self.data,self.n)
    self.PSD = self.fhat+np.conj(self.fhat)/self.n
    self.freq=(1/(self.n)) *np.arange(self.n)
    self.L=np.arange(1,np.floor(self.n/2),dtype="int")
    self.forier = (self.freq[self.L], abs(self.PSD[self.L]))
    self.square=[]
    self.squarePlot=[]
    self.squareAdded=[]
    self.squareForier= []
    self.squareAmp=0
    self.squareFreq=0
    self.squareN=0
    self.squarePSD=0
    self.square
    
  def plotSound(self):
    plt.rcParams['figure.figsize'] = [30,3]
    plt.plot(self.data)

  def plotForier(self):
    plt.plot(self.forier[0],self.forier[1])

  def addSquare(self, amplitude, frequency, time):
    dt=0.001
    t=np.arange(0,1,dt)
    f=signal.square(amplitude*(2 * np.pi * frequency * t))
    self.square = f

    n=len(f)
    fhat=np.fft.fft(f,n)
    PSD = fhat+np.conj(fhat)/n
    freq=(1/(n)) *np.arange(n)
    L=np.arange(1,np.floor(n/2),dtype="int")
    self.squareForier = (freq[L], abs(PSD[L]))

    squareAdded=self.data
    for i in range(len(f)):
      squareAdded[i+time]+=f[i]
    self.squareAdded=squareAdded
    self.squareAmp = amplitude
    self.squareFreq= frequency
    
  def plotSquareForier(self):
    plt.plot(self.squareForier[0],self.squareForier[1])


  def plotSquare(self):
    plt.rcParams['figure.figsize'] = [5,5]
    t = np.linspace(0, 1, 1000, endpoint=True)
    plt.title(f'Sqaure wave - {self.squareFreq} Hz, {self.squareAmp} metres, sampled at 1000 Hz /second')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.ylim(-2, 2)
    plt.plot(t, self.square)
    plt.show()

  def plotCombined(self):
    plt.rcParams['figure.figsize'] = [30,3]
    plt.plot(self.squareAdded)
    plt.show()

# %%
small=soundSample("eisen.mp3")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
small.addSquare(1,5,1000)

# %%
small.plotSound()

# %%
ffit = np.fft.ifft(small.fhat) 
plt.plot(small.t,ffit)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ffit = np.fft.ifft(self.squarForier.fhat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-c7ba4f212f6c> in <module>()
# ----> 1 ffit = np.fft.ifft(squarForier.fhat)
#
# NameError: name 'squarForier' is not defined

# %%
small.plotSquareForier()

# %%
#transformed music
def transform_and_plot(dt,data):
  #incriment of x axis, try 0.001, 0.1 or 1
  n=len(data)
  fhat=np.fft.fft(data,n)
  PSD = fhat+np.conj(fhat)/n
  freq=(1/(dt*n)) *np.arange(n)
  L=np.arange(1,np.floor(n/2),dtype="int")

  fig,axs = plt.subplots(2,1)

  plt.sca(axs[0])
  plt.plot(data)
  #plt.xlim(data[0],data[-1])


  plt.sca(axs[1])
  plt.plot(freq[L], abs(PSD[L]))
  return(max(abs(PSD[L])))
  #plt.xlim(freq[L[0]],freq[L[-1]])

# %%
#transformed music
def getmax(dt,data):
  #incriment of x axis, try 0.001, 0.1 or 1
  n=len(data)
  fhat=np.fft.fft(data,n)
  PSD = fhat+np.conj(fhat)/n
  freq=(1/(dt*n)) *np.arange(n)
  L=np.arange(1,np.floor(n/2),dtype="int")

  #plt.xlim(data[0],data[-1])

  return(max(abs(PSD[L])))
  #plt.xlim(freq[L[0]],freq[L[-1]])

# %%
#transformed music comparison
def transform_and_compare(dt,data, datazero):
  plt.rcParams['figure.figsize'] = [30,12]

  #Whole data plot
  #incriment of x axis, try 0.001, 0.1 or 1

  t=np.arange(0,len(data),dt)
  n=len(data)
  fhat=np.fft.fft(data,n)
  PSD = fhat+np.conj(fhat)/n
  freq=(1/(dt*n)) *np.arange(n)
  L=np.arange(1,np.floor(n/2),dtype="int")

  fig,axs = plt.subplots(3,1)

  plt.sca(axs[0])
  plt.plot(data)
  #plt.xlim(data[0],data[-1])

  #fourier transform
  plt.sca(axs[1])
  plt.plot(freq[L], abs(PSD[L]))
  #plt.xlim(freq[L[0]],freq[L[-1]])


  

  #square wave only
  plt.sca(axs[2])
  maxvalue = getmax(dt,datazero)
  indices = abs(PSD) > maxvalue
  PSDClean=PSD * indices
  fhat=indices * fhat
  ffit = np.fft.ifft(fhat) #This is the inverse fourier tranform I think
  plt.plot(t,ffit)

  isolated_zip = zip(t,ffit)


  zipped_list = list(isolated_zip)
  #return(zipped_list)
  return(ffit,max(ffit))
  plt.show()

# %%
small.addSquare(1,5,2000)

# %%
plt.plot(small.square)

# %%
len(data1)
# Out:
# 118144

# %%
len(t)
# Out:
# 118144

# %%
combined=data1+f

# %%
plt.plot(data1)

# %%
plt.plot(combined)

# %%
dt2=1/len(data1)
t=np.arange(0,1,dt2)
f=np.sin(1*np.pi*10*t)
plt.plot(t,f)

# %%
dt=0.001
t=np.arange(0,1,dt)
f=np.sin(2*np.pi*20*t)
plt.plot(t,f)

# %%
dt=0.001
t=np.arange(0,1,dt)
f=np.sin(2*np.pi*20*t)
f2=signal.square(2 * np.pi * 5 * t)
square=[0]*len(data1)
for i in range(len(f)):
  square[i+math.floor(len(data1)/2)]+=f2[i]

# %%
plt.plot(f2)

# %%
from scipy import signal

import matplotlib.pyplot as plot

import numpy as np

 

# Sampling rate 1000 hz / second

t = np.linspace(0, 1, 1000, endpoint=True)

thing=signal.square(2 * np.pi * 10 * t)
thing=thing/2

# Plot the square wave signal (Hz are multiplied by t)

plot.plot(t, thing)

 

# Give a title for the square wave plot

plot.title('Sqaure wave - 5 Hz sampled at 1000 Hz /second')

 

# Give x axis label for the square wave plot

plot.xlabel('Time')

 

# Give y axis label for the square wave plot

plot.ylabel('Amplitude')

 

plot.grid(True, which='both')

 

# Provide x axis and line color

plot.axhline(y=0, color='k')

 

# Set the max and min values for y axis

plot.ylim(-2, 2)

 

# Display the square wave drawn

plot.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-70adbc95a25d> in <module>()
# ----> 1 squarewave(0.2,0.05,1,0.5)
#
# <ipython-input-69-83549fbc1f67> in __init__(self, amplitude, period, timestep, duty, offset, phase)
#      19           phase_array = 2 * np.pi * (time_array / period)
#      20           phase_array += phase
# ---> 21           wave = amplitude * square(phase_array, duty) + offset
#      22           super(SquareWaveVelocityProfile, self).__init__(wave, period, timestep)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
# Out:
# 0

# %%
plt.plot(square)

# %%
#transformed music comparison
def transform_and_compare(dt,data, datazero,squarewave):
  plt.rcParams['figure.figsize'] = [30,12]

  #Whole data plot
  #incriment of x axis, try 0.001, 0.1 or 1

  t=np.arange(0,len(data),dt)
  n=len(data)
  fhat=np.fft.fft(data,n)
  PSD = fhat+np.conj(fhat)/n
  freq=(1/(dt*n)) *np.arange(n)
  L=np.arange(1,np.floor(n/2),dtype="int")

  fig,axs = plt.subplots(5,1)

  plt.sca(axs[1])
  plt.plot(data)
  #plt.xlim(data[0],data[-1])

  plt.sca(axs[0])
  plt.plot(datazero)

  #fourier transform
  plt.sca(axs[2])
  plt.plot(freq[L], abs(PSD[L]))
  #plt.xlim(freq[L[0]],freq[L[-1]])


 

  #cleaned plot
  plt.sca(axs[3])
  maxvalue = getmax(dt,datazero)
  indices = abs(PSD) > maxvalue
  PSDClean=PSD * indices
  fhat=indices * fhat
  ffit = np.fft.ifft(fhat) #This is the inverse fourier tranform I think
  plt.plot(t,ffit)

  isolated_zip = zip(t,ffit)

#square transform
  plt.sca(axs[4])
  t2=np.arange(0,len(squarewave),dt)
  n2=len(squarewave)
  fhat2=np.fft.fft(squarewave,n2)
  PSD2 = fhat2+np.conj(fhat2)/n2
  freq2=(1/(dt*n2)) *np.arange(n2)
  L2=np.arange(1,np.floor(n/2),dtype="int")
  plt.plot(freq2[L2], abs(PSD2[L2]))

  zipped_list = list(isolated_zip)
  #return(zipped_list)
  return(ffit,max(ffit))
  plt.show()

# %%
isolated=transform_and_compare(1,data5,data1,square)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-9015b0950b7e> in <module>()
# ----> 1 isolated=transform_and_compare(1,data5,data1,square)
#
# <ipython-input-57-bd2cacc66c8c> in transform_and_compare(dt, data, datazero, squarewave)
#      49   freq2=(1/(dt*n2)) *np.arange(n2)
#      50   L2=np.arange(1,np.floor(n/2),dtype="int")
# ---> 51   plt.plot(freq2[L2], abs(PSD2[L2]))
#      52
#      53   zipped_list = list(isolated_zip)
#
# IndexError: index 36824 is out of bounds for axis 0 with size 36824

# %%
square="smallsquareonly.mp3"

# %%
ffit=isolated[0]
t=isolated[1]
q1, q3= np.percentile(ffit,[25,75], interpolation = 'midpoint')
iqr = q3 - q1
upper_bound = q3 +(1.5 * iqr)
counter=0
for item in ffit:
  if item> upper_bound:
    counter+=1
ffit1=ffit>upper_bound

is_signal=ffit>0.59

# %%
from scipy.signal import find_peaks

# %%
peaks, properties = find_peaks(ffit, prominence=0.6, width=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
peaks
# Out:
# array([], dtype=int64)

# %%
import plotly.graph_objects as go

import numpy as np
import pandas as pd
import scipy

from scipy import signal

np.random.seed(1)

x = np.linspace(0, 10, 100)
y = np.sin(x)
noise = 2 * np.random.random(len(x)) - 1 # uniformly distributed between -1 and 1
y_noise = y + noise

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker=dict(size=2, color='black'),
    name='Sine'
))

fig.add_trace(go.Scatter(
    x=x,
    y=y_noise,
    mode='markers',
    marker=dict(
        size=6,
        color='royalblue',
        symbol='circle-open'
    ),
    name='Noisy Sine'
))

fig.add_trace(go.Scatter(
    x=x,
    y=signal.savgol_filter(y,
                           53, # window size used for filtering
                           3), # order of fitted polynomial
    mode='markers',
    marker=dict(
        size=6,
        color='mediumpurple',
        symbol='triangle-up'
    ),
    name='Savitzky-Golay'
))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a659f6da-d9e7-4739-8874-481e025535aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a659f6da-d9e7-4739-8874-481e025535aa")) {
#                     Plotly.newPlot(
#                         'a659f6da-d9e7-4739-8874-481e025535aa',
#                         [{"marker": {"color": "black", "size": 2}, "mode": "markers", "name": "Sine", "type": "scatter", "x": [0.0, 0.10101010101010101, 0.20202020202020202, 0.30303030303030304, 0.40404040404040403, 0.5050505050505051, 0.6060606060606061, 0.7070707070707071, 0.8080808080808081, 0.9090909090909091, 1.0101010101010102, 1.1111111111111112, 1.2121212121212122, 1.3131313131313131, 1.4141414141414141, 1.5151515151515151, 1.6161616161616161, 1.7171717171717171, 1.8181818181818181, 1.9191919191919191, 2.0202020202020203, 2.121212121212121, 2.2222222222222223, 2.323232323232323, 2.4242424242424243, 2.525252525252525, 2.6262626262626263, 2.727272727272727, 2.8282828282828283, 2.929292929292929, 3.0303030303030303, 3.131313131313131, 3.2323232323232323, 3.3333333333333335, 3.4343434343434343, 3.5353535353535355, 3.6363636363636362, 3.7373737373737375, 3.8383838383838382, 3.9393939393939394, 4.040404040404041, 4.141414141414141, 4.242424242424242, 4.343434343434343, 4.444444444444445, 4.545454545454545, 4.646464646464646, 4.747474747474747, 4.848484848484849, 4.94949494949495, 5.05050505050505, 5.151515151515151, 5.252525252525253, 5.353535353535354, 5.454545454545454, 5.555555555555555, 5.656565656565657, 5.757575757575758, 5.858585858585858, 5.959595959595959, 6.0606060606060606, 6.161616161616162, 6.262626262626262, 6.363636363636363, 6.4646464646464645, 6.565656565656566, 6.666666666666667, 6.767676767676767, 6.8686868686868685, 6.96969696969697, 7.070707070707071, 7.171717171717171, 7.2727272727272725, 7.373737373737374, 7.474747474747475, 7.575757575757575, 7.6767676767676765, 7.777777777777778, 7.878787878787879, 7.979797979797979, 8.080808080808081, 8.181818181818182, 8.282828282828282, 8.383838383838384, 8.484848484848484, 8.585858585858587, 8.686868686868687, 8.787878787878787, 8.88888888888889, 8.98989898989899, 9.09090909090909, 9.191919191919192, 9.292929292929292, 9.393939393939394, 9.494949494949495, 9.595959595959595, 9.696969696969697, 9.797979797979798, 9.8989898989899, 10.0], "y": [0.0, 0.1008384202581046, 0.2006488565226854, 0.2984138044476411, 0.3931366121483298, 0.48385164043793466, 0.5696341069089657, 0.6496095135057065, 0.7229625614794605, 0.7889454628442574, 0.8468855636029834, 0.8961922010299563, 0.9363627251042848, 0.9669876227092996, 0.9877546923600838, 0.9984522269003895, 0.9989711717233568, 0.9893062365143401, 0.9695559491823237, 0.9399216514301312, 0.9007054462029555, 0.8523071179396752, 0.7952200570230491, 0.7300262299764464, 0.6573902466827755, 0.5780525851065732, 0.4928220425889235, 0.40256749066949654, 0.30820901749007684, 0.2107085480771929, 0.11106003812412972, 0.010279341240534697, -0.09060614703340773, -0.19056796287548539, -0.28858705872043244, -0.38366419180611233, -0.47483011082223947, -0.5611554368152017, -0.6417601376193878, -0.7158224992291902, -0.7825875026542022, -0.8413745208608701, -0.8915842573351402, -0.9327048555318336, -0.9643171169287782, -0.9860987744909296, -0.9978277779792126, -0.9993845576124357, -0.9907532430056771, -0.9720218249588334, -0.9433812584459996, -0.9051235159501367, -0.8576386109880517, -0.8014106221689697, -0.7370127583189133, -0.6651015149788224, -0.5864099818472351, -0.5017403693939113, -0.4119558308308628, -0.31797166281061867, -0.22074597455506334, -0.12126992053716677, -0.020557596287260064, 0.08036429967028173, 0.18046693235991093, 0.27872981867755725, 0.37415123057121996, 0.4657584070256517, 0.5526174707464059, 0.6338429484489058, 0.7086067976992182, 0.7761468482835805, 0.8357745720522589, 0.8868821020290788, 0.9289484292312513, 0.9615447140268235, 0.9843386578838236, 0.9970978909438748, 0.9996923408861117, 0.9920955589323228, 0.9743849894755358, 0.9467411805833543, 0.9094459434244625, 0.8628794793817836, 0.8075165041395626, 0.7439214082568444, 0.6727425035622647, 0.5947054140244975, 0.510605678474283, 0.4213006405886069, 0.32770070881349983, 0.23076007532505177, 0.13146698864295842, 0.03083367906114098, -0.07011396040064677, -0.170346832328096 ...

# %%
ffitsort=sorted(ffit)

# %%
counter/len(ffit)
# Out:
# 0.0394638807904114

# %%
plot=ffit==max(ffit)
sum(plot)
# Out:
# 1

# %%
import pandas as pd
df=pd.DataFrame(plot)
df.to_csv("plot.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-23b805610565> in <module>()
#       4       for j in range(len(plot)):
#       5         if j>i:
# ----> 6           if plot[j]==True and j-i>1:
#       7             distances.append(j-i)
#
# KeyboardInterrupt:

# %%
has_value=has_value.tolist()

# %%
indices=[i for i, x in enumerate(plot) if x]

# %%
max(ffit)
# Out:
# (0.8694331681965269+4.931011744962758e-17j)

# %%
is_max=ffit>=max(ffit)-std

# %%
trues=sum(is_max)
trues
# Out:
# 38

# %%
plt.plot(indices)

# %%
dct = dict((y, x) for x, y in isolated)
print(dct)

# %%
print(len(set(dct)))
print(len(dct))
# Out:
# 1975680
# 1975680

# %%
flipped = {}
  
for key, value in dct.items():
    if value not in flipped:
        flipped[value] = key
    else:
        flipped[value].append(key, value)

# %%
repeat = {}
newdct=dct
for key, value in dct.items():
    if value not in flipped:
      del newdict[key]

# %%
# Out:
# {(0.34024341261598534-1.8413805915389703e-18j): 0,
#  (0.33930977601052537+1.611208017596599e-18j): 1,
#  (0.33456996419830765-2.301725739423713e-18j): 2,
#  (0.3261871819001116-4.603451478847426e-19j): 3,
#  (0.3144334803422694-3.222416035193198e-18j): 4,
#  (0.2996739809607055+1.8413805915389703e-18j): 5,
#  (0.28234594035181804-9.206902957694851e-19j): 6,
#  (0.2629340041704375-1.611208017596599e-18j): 7,
#  (0.24194324031654468+3.222416035193198e-18j): 8,
#  (0.21987168058582238+4.833624052789797e-18j): 9,
#  (0.1971841259506032-4.603451478847426e-19j): 10,
#  (0.17428888213193075+2.301725739423713e-18j): 11,
#  (0.15151889495124635+3.222416035193198e-18j): 12,
#  (0.12911846204738095+4.143106330962683e-18j): 13,
#  (0.10723632810522853+4.603451478847426e-19j): 14,
#  (0.08592554896369954+0j): 15,
#  (0.0651500634692901-4.603451478847426e-18j): 16,
#  (0.04479746994838388+5.5241417746169105e-18j): 17,
#  (0.0246970956183091-5.5241417746169105e-18j): 18,
#  (0.004642098885373615+1.8413805915389703e-18j): 19,
#  (-0.015585920911267379+5.5241417746169105e-18j): 20,
#  (-0.03619149678831079-4.603451478847426e-18j): 21,
#  (-0.057340794801048346-5.5241417746169105e-18j): 22,
#  (-0.07913972568264899+1.8413805915389703e-18j): 23,
#  (-0.10161617949855607-1.8413805915389703e-18j): 24,
#  (-0.12470762438770948+1.5651735028081246e-17j): 25,
#  (-0.14825495772541855+5.5241417746169105e-18j): 26,
#  (-0.17200308663979372+1.2889664140772792e-17j): 27,
#  (-0.17368791107783818-9.206902957694852e-18j): 982,
#  (-0.19708807992980754-1.1048283549233821e-17j): 983,
#  (-0.2201648608201763+3.222416035193198e-18j): 984,
#  (-0.24247323874820254+6.444832070386396e-18j): 985,
#  (-0.2635225808207533+1.2889664140772792e-17j): 986,
#  (-0.2828016370896354+5.0637966267321686e-18j): 987,
#  (-0.29980563992227377-2.301725739423713e-19j): 988,
#  (-0.31406377578187955+4.718537765818611e-18j): 989,
#  (-0.32516527312819044+2.301725739423713e-18j): 990,
#  (-0.3327824345569415-4.603451478847426e-19j): 991,
#  (-0.3366891347989873+0j): 992,
#  (-0.3367735961886078+7.13534979221351e-18j): 993,
#  (-0.333044620766203-4.143106330962683e-18j): 994,
#  (-0.3256308793126197+2.301725739423713e-18j): 995,
#  (-0.3147733048268714+3.222416035193198e-18j): 996,
#  (-0.3008110820568242+5.178882913703354e-18j): 997,
#  (-0.2841621366783534+4.660994622333018e-18j): 998,
#  (-0.265299380697452+5.5816849181025036e-18j): 999,
#  ...}

# %%
maxPSDNormal=transform_and_plot(0.1,data1)
maxPSDNormal
# Out:
# 7240.345649323176

# %%
maxPSDadded=transform_and_plot(0.1,data2)
maxPSDadded
# Out:
# 8021.657765167709

# %%
indices=PSD

# %%
#filter out all but square wave?

 #incriment of x axis, try 0.001, 0.1 or 1
n=len(data2)
fhat=np.fft.fft(data2,n)
PSD = fhat+np.conj(fhat)/n
freq=(1/(dt*n)) *np.arange(n)
L=np.arange(1,np.floor(n/2),dtype="int")

fig,axs = plt.subplots(2,1)

plt.sca(axs[0])
plt.plot(data2)
#plt.xlim(data[0],data[-1])


plt.sca(axs[1])
plt.plot(freq[L], abs(PSD[L]))
#plt.xlim(freq[L[0]],freq[L[-1]])
plt.show()

maxPSD=max(abs(PSD[L]))
indices = PSD > maxPSDNormal
PSDclean=PSD * indices
fhat=indices*fhat
ffit = np.fft.ifft(fhat)

plt.plot(freq[L],PSDclean[L])
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
squaredata=data
index=[]
for i in range (len(squaredata)):
    if i>len(squaredata/7) and i<len(squaredata/6):
        index.append(2)
    else:
        index.append(0)

donedata=squaredata+index

# %%
len(data)
# Out:
# 8807064
# 8807064

# %%
#transformed music
dt=0.1  #incriment of x axis
n=len(data)
fhat=np.fft.fft(donedata,n)
PSD = fhat+np.conj(fhat)/n
freq=(1/(dt*n)) *np.arange(n)
L=np.arange(1,np.floor(n/2),dtype="int")

fig,axs = plt.subplots(2,1)

plt.sca(axs[0])
plt.plot(donedata)
#plt.xlim(data[0],data[-1])
plt.legend()


plt.sca(axs[1])
plt.plot(freq[L], abs(PSD[L]))
#plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
def plot_m_s(signal, title, sr):
    ft = np.fft.fft(signal)
    mag_spectrum=np.abs(ft)

    #plot mag spectrum

    frequency = np.linspace(0,sr,len(mag_spectrum))
    plt.plot(frequency, mag_spectrum)
    plt.xlabel("Frequency in Hz")
    plt.title(title)
    plt.show()

# %%
plot_m_s(data,"nina",sr)
